# %%
import pandas as pd

file_path_1= '../data/raw/EDF/bilan-social-d-edf-sa-effectifs-et-repartition-par-age-statut-et-sexe.csv'
file_path_2= '../data/raw/EDF/bilan-social-d-edf-sa-salaries-en-situation-de-handicap.csv'
effectifs_df = pd.read_csv(file_path_1, delimiter=';')
handicap_df=pd.read_csv(file_path_2, delimiter=';')

# %%
effectifs_df
# Out:
#       Année Perimètre juridique Perimètre spatial Spatial perimeter  \
# 0      2023              EDF SA            France            France
# 1      2023              EDF SA            France            France
# 2      2023              EDF SA            France            France
# 3      2023              EDF SA            France            France
# 4      2023              EDF SA            France            France
# ...     ...                 ...               ...               ...
# 2317   2017              EDF SA            France            France
# 2318   2017              EDF SA            France            France
# 2319   2017              EDF SA            France            France
# 2320   2017              EDF SA            France            France
# 2321   2017              EDF SA            France            France
#
#                                     Indicateur  \
# 0                                     Effectif
# 1                                     Effectif
# 2                                     Effectif
# 3                                     Effectif
# 4                                     Effectif
# ...                                        ...
# 2317  Embauches de salariés de moins de 25 ans
# 2318                                Démissions
# 2319                                Démissions
# 2320                                Démissions
# 2321                                Démissions
#
#                                   Indicator      Type de contrat  \
# 0                                 Workforce  Non statutaires CDI
# 1                                 Workforce  Non statutaires CDD
# 2                                 Workforce  Non statutaires CDD
# 3                                 Workforce  Non statutaires CDD
# 4                                 Workforce          Statutaires
# ...                                     ...                  ...
# 2317  Hires of Employees Under 25 Years Old  Non statutaires CDD
# 2318                           Resignations          Statutaires
# 2319                           Resignations          Statutaires
# 2320                           Resignations  Non statutaires CDI
# 2321                           Resignations  Non statutaires CDI
#
#               Type of contract    Collège Employee category  ... Nationalité  \
# 0      Permanent non-staturory      Cadre          Managers  ...         NaN
# 1     Fixed-term non-statutory      Cadre          Managers  ...         NaN
# 2     Fixed-term non-statutory   Maîtrise       Supervisors  ...         NaN
# 3     Fixed-term non-statutory  Exécution        Operatives  ...         NaN
# 4                    Statutory      Cadre          Managers  ...         NaN
# ...                        ...        ...               ...  ...         ...
# 2317  Fixed-term non-statutory  Exécution        Operatives  ...         NaN
# 2318                 Statutory      Cadre          Managers  ...         NaN
# 2319                 Statutory   Maîtrise       Supervisors  ...         NaN
# 2320   Permanent non-staturory   Maîtrise       Supervisors  ...         NaN
# 2321   Permanent non-staturory   Maîtrise       Supervisors  ...         NaN
#
#      Nationality Ancienneté Seniority    Tranche d'âge    Age bracket  Valeur  \
# 0            NaN        NaN       NaN  Moins de 25 ans   Less than 25     9.0
# 1            NaN        NaN       NaN  Moins de 25 ans   Less than 25    19.0
# 2            NaN        NaN       NaN  Moins de 25 ans   Less than 25   683.0
# 3            NaN        NaN       NaN  Moins de 25 ans   Less than 25  1216.0
# 4            NaN        NaN       NaN   De 25 à 35 ans  From 25 to 35  2046.0
# ...          ...        ...       ...              ...            ...     ...
# 2317         NaN        NaN       NaN              NaN            NaN   367.0
# 2318         NaN        NaN       NaN              NaN            NaN    87.0
# 2319         NaN        NaN       NaN              NaN            NaN    10.0
# 2320         NaN        NaN       NaN              NaN            NaN     0.0
# 2321         NaN        NaN       NaN              NaN            NaN     0.0
#
#        Unité    Unit Chapitre du bilan social
# 0     nombre  number                   §1.1.6
# 1     nombre  number                   §1.1.6
# 2     nombre  number                   §1.1.6
# 3     nombre  number                   §1.1.6
# 4     nombre  number                   §1.1.6
# ...      ...     ...                      ...
# 2317  nombre  number                   §1.3.3
# 2318  nombre  number                   §1.4.2
# 2319  nombre  number                   §1.4.2
# 2320  nombre  number                   §1.4.2
# 2321  nombre  number                   §1.4.2
#
# [2322 rows x 26 columns]

# %%
effectifs_df.rename(columns={
    'Genre': 'Sexe',
    'Type de contrat': 'Contrat',
    'Collège': 'Categorie',
    'Tranche d\'âge': 'Tranche_age',
    'Valeur': 'Valeur_effectifs',
    'Unité': 'Unite_effectifs'
}, inplace=True)

handicap_df.rename(columns={
    'Genre': 'Sexe',
    'Type de contrat': 'Contrat',
    'Collège': 'Categorie',
    'Valeur': 'Valeur_handicap',
    'Unité': 'Unite_handicap'
}, inplace=True)

# %%
# Normaliser les valeurs de la colonne "Sexe"
effectifs_df['Sexe'] = effectifs_df['Sexe'].str.lower().map({'homme': 'Homme', 'femme': 'Femme'})
handicap_df['Sexe'] = handicap_df['Sexe'].str.lower().map({'homme': 'Homme', 'femme': 'Femme'})

# %%
# Supprimer les doublons
effectifs_df.drop_duplicates(inplace=True)
handicap_df.drop_duplicates(inplace=True)

# Gérer les valeurs manquantes
effectifs_df.fillna({'Sexe': 'Non spécifié'}, inplace=True)
handicap_df.fillna({'Sexe': 'Non spécifié'}, inplace=True)

# 3. Ajout d'une colonne "Source"
effectifs_df['Source'] = 'Effectifs'
handicap_df['Source'] = 'Handicap'

# %%
# Aligner les colonnes communes
columns_to_keep = ['Année', 'Sexe', 'Contrat', 'Categorie', 'Valeur_effectifs', 'Valeur_handicap', 'Source']
effectifs_df = effectifs_df[['Année', 'Sexe', 'Contrat', 'Categorie', 'Valeur_effectifs', 'Source']]
handicap_df = handicap_df[['Année', 'Sexe', 'Contrat', 'Categorie', 'Valeur_handicap', 'Source']]

# %%
# Fusionner les deux jeux de données
merged_df = pd.merge(effectifs_df, handicap_df, on=['Année', 'Sexe', 'Contrat', 'Categorie', 'Source'], how='outer')
# Calculer le pourcentage d’hommes et de femmes
total_effectifs = merged_df.groupby(['Categorie'])['Valeur_effectifs'].transform('sum')
merged_df['Pourcentage_sexe'] = (merged_df['Valeur_effectifs'] / total_effectifs) * 100

# Calculer la part des personnes en situation de handicap dans les effectifs totaux
merged_df['Part_handicap'] = (merged_df['Valeur_handicap'] / merged_df['Valeur_effectifs']) * 100

# Calculer l'évolution annuelle (croissance/décroissance)
merged_df['Evolution_annuelle'] = merged_df.groupby(['Sexe', 'Contrat', 'Categorie'])['Valeur_effectifs'].pct_change() * 100
# Out:
# /tmp/ipykernel_142351/2629973396.py:11: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   merged_df['Evolution_annuelle'] = merged_df.groupby(['Sexe', 'Contrat', 'Categorie'])['Valeur_effectifs'].pct_change() * 100

# %%
merged_df.to_csv("../data/processed/edf_bilan_social_preparé.csv", index=False)

# %%
effectifs_df
# Out:
#       Année   Sexe              Contrat  Categorie  Valeur_effectifs  \
# 0      2023  Homme  Non statutaires CDI      Cadre               9.0
# 1      2023  Femme  Non statutaires CDD      Cadre              19.0
# 2      2023  Femme  Non statutaires CDD   Maîtrise             683.0
# 3      2023  Homme  Non statutaires CDD  Exécution            1216.0
# 4      2023  Femme          Statutaires      Cadre            2046.0
# ...     ...    ...                  ...        ...               ...
# 2317   2017  Femme  Non statutaires CDD  Exécution             367.0
# 2318   2017  Homme          Statutaires      Cadre              87.0
# 2319   2017  Femme          Statutaires   Maîtrise              10.0
# 2320   2017  Homme  Non statutaires CDI   Maîtrise               0.0
# 2321   2017  Femme  Non statutaires CDI   Maîtrise               0.0
#
#          Source
# 0     Effectifs
# 1     Effectifs
# 2     Effectifs
# 3     Effectifs
# 4     Effectifs
# ...         ...
# 2317  Effectifs
# 2318  Effectifs
# 2319  Effectifs
# 2320  Effectifs
# 2321  Effectifs
#
# [2322 rows x 6 columns]

# %%
handicap_df
# Out:
#      Année          Sexe              Contrat  Categorie  Valeur_handicap  \
# 0     2023         Femme          Statutaires      Cadre            343.0
# 1     2023         Homme  Non Statutaires CDI   Maîtrise              0.0
# 2     2023         Homme  Non Statutaires CDD      Cadre              0.0
# 3     2023  Non spécifié          Statutaires   Maîtrise             49.0
# 4     2023  Non spécifié  Non Statutaires CDD      Cadre              0.0
# ..     ...           ...                  ...        ...              ...
# 184   2017         Femme  Non Statutaires CDI  Exécution              1.0
# 185   2017         Homme  Non Statutaires CDD      Cadre              0.0
# 186   2017         Femme  Non Statutaires CDD      Cadre              0.0
# 187   2017         Femme  Non Statutaires CDD   Maîtrise             10.0
# 188   2017  Non spécifié  Non Statutaires CDI      Cadre              0.0
#
#        Source
# 0    Handicap
# 1    Handicap
# 2    Handicap
# 3    Handicap
# 4    Handicap
# ..        ...
# 184  Handicap
# 185  Handicap
# 186  Handicap
# 187  Handicap
# 188  Handicap
#
# [189 rows x 6 columns]

# %%
merged_df
# Out:
#       Année          Sexe              Contrat  Categorie  Valeur_effectifs  \
# 0      2017         Femme  Non Statutaires CDD      Cadre               NaN
# 1      2017         Femme  Non Statutaires CDD  Exécution               NaN
# 2      2017         Femme  Non Statutaires CDD   Maîtrise               NaN
# 3      2017         Femme  Non Statutaires CDI      Cadre               NaN
# 4      2017         Femme  Non Statutaires CDI  Exécution               NaN
# ...     ...           ...                  ...        ...               ...
# 2506   2023  Non spécifié  Non Statutaires CDI  Exécution               NaN
# 2507   2023  Non spécifié  Non Statutaires CDI   Maîtrise               NaN
# 2508   2023  Non spécifié          Statutaires      Cadre               NaN
# 2509   2023  Non spécifié          Statutaires  Exécution               NaN
# 2510   2023  Non spécifié          Statutaires   Maîtrise               NaN
#
#         Source  Valeur_handicap  Pourcentage_sexe  Part_handicap  \
# 0     Handicap              0.0               NaN            NaN
# 1     Handicap             23.0               NaN            NaN
# 2     Handicap             10.0               NaN            NaN
# 3     Handicap              1.0               NaN            NaN
# 4     Handicap              1.0               NaN            NaN
# ...        ...              ...               ...            ...
# 2506  Handicap              0.0               NaN            NaN
# 2507  Handicap              0.0               NaN            NaN
# 2508  Handicap             32.0               NaN            NaN
# 2509  Handicap              8.0               NaN            NaN
# 2510  Handicap             49.0               NaN            NaN
#
#       Evolution_annuelle
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 2506                 NaN
# 2507                 NaN
# 2508                 NaN
# 2509                 NaN
# 2510                 NaN
#
# [2511 rows x 10 columns]

# %%
merged_df.to_csv("../data/processed/EDF_effectifs_handi.csv", index=False)
